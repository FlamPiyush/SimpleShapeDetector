# %%
import numpy as np
import cv2
import random

vid = cv2.VideoCapture(0)
shapes = []
check_shapes = {
   "tri":0,
    "square" : 0,
    "pent" :0,
    "hex":0,
    "sept" :0,
    "oct" :0,
    "nana":0,
    "dec":0
}
no_sides = {
    "tri":11,
    "square" : 12,
    "pent" :14,
    "hex":6,
    "sept" :7,
    "oct" :8,
    "nana":9,
    "dec":10
}
name_shape = {v: k for k, v in no_sides.items()}
i = 0
start_rec = False
while(True):
      
    # Capture the video frame
    # by frame
    ret, img = vid.read()
    var = cv2.waitKey(1)
    if  var & 0xFF == ord('r'):##start recording
        start_rec = True
        imgGrey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #     imgGrey = cv2.blur(imgGrey,(3,3))
    #     _, thrash = cv2.threshold(imgGrey, 175, 255, cv2.THRESH_BINARY)
        thrash = cv2.Canny(imgGrey,100,200)
    #     kernel = np.ones((5,5), np.uint8)
    #     thrash = cv2.dilate(thrash,kernel,iterations=1)
    #     thrash = cv2.erode(thrash,kernel,iterations=1)
        contours, _ = cv2.findContours(thrash, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
        closed_contours = []
        for i in contours:
            if cv2.contourArea(i) > cv2.arcLength(i, True):
                closed_contours.append(i)

        cv2.imshow("img", thrash)
        for contour in closed_contours:
            i = random.randrange(0, 255, 20)
            j = random.randrange(0, 255, 20)
            k = random.randrange(0, 255, 20)
            approx = cv2.approxPolyDP(contour, 0.01* cv2.arcLength(contour, True), True)
            cv2.drawContours(img, [contour], 0, (i, j, k), 2)
            x = approx.ravel()[0]
            y = approx.ravel()[1] - 5
            try:
                if name_shape[len(approx)] not in shapes:
                    shapes.append(name_shape[len(approx)])
            except:
                print(None)
#             elif len(approx) == 14:
#                 cv2.putText(img, "Pentagon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0))
#                 if "pentagon" not in shapes:
#                     shapes.append("Pentagon")
#             elif len(approx) == 6:
#                 cv2.putText(img, "Hexagon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0))
#                 if "Hexagon" not in shapes:
#                     shapes.append("Hexagon")
#             elif len(approx) == 7:
#                 cv2.putText(img, "Heptagon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0))
#                 if "Heptagon" not in shapes:
#                     shapes.append("Heptagon")
#             elif len(approx) == 8:
#                 cv2.putText(img, "Octagon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0))
#                 if "Octagon" not in shapes:
#                     shapes.append("Octagon")
#             elif len(approx) == 11:
#                 cv2.putText(img, "11gon", (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.5, (255, 0, 0))
#                 if "11gon" not in shapes:
#                     shapes.append("11gon")
        print("shapes::::", shapes)
        for i in shapes:
            check_shapes[i] +=1
        shapes = []
       
        
    

    cv2.imshow("shapes", img)
    if var & 0xFF == ord('q'):
        break
    
    
# After the loop release the cap object
vid.release()
cv2.destroyAllWindows()
# Out:
# shapes:::: ['tri', 'oct', 'dec']
# None
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'tri', 'square', 'sept', 'hex', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'nana', 'tri', 'sept', 'dec', 'square', 'pent']
# None
# None
# shapes:::: ['tri', 'square', 'sept', 'dec', 'nana', 'oct', 'hex', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'nana', 'square', 'tri', 'sept', 'hex', 'dec', 'pent']
# None
# None
# None
# shapes:::: ['dec', 'oct', 'sept', 'nana', 'tri', 'hex', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'tri', 'sept', 'square', 'hex']
# None
# None
# None
# None
# shapes:::: ['square', 'dec', 'oct', 'tri', 'sept', 'nana', 'hex']
# None
# None
# None
# None
# None
# shapes:::: ['square', 'oct', 'nana', 'tri', 'dec', 'sept', 'pent']
# None
# None
# None
# None
# shapes:::: ['nana', 'square', 'hex', 'oct', 'tri', 'sept', 'dec']
# None
# None
# None
# None
# shapes:::: ['oct', 'nana', 'dec', 'sept', 'tri', 'square']
# None
# None
# shapes:::: ['hex', 'oct', 'nana', 'dec', 'tri', 'sept', 'pent', 'square']
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'dec', 'tri', 'nana', 'hex', 'square']
# None
# None
# None
# shapes:::: ['hex', 'oct', 'tri', 'dec', 'sept', 'square', 'nana', 'pent']
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'tri', 'nana', 'sept', 'hex', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'nana', 'tri', 'dec', 'hex', 'pent', 'square']
# None
# shapes:::: ['hex', 'oct', 'tri', 'nana', 'square', 'dec', 'sept', 'pent']
# None
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'sept', 'hex', 'tri', 'square', 'pent']
# None
# None
# None
# shapes:::: ['hex', 'dec', 'tri', 'oct', 'nana', 'sept', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'sept', 'tri', 'square']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'nana', 'tri', 'hex', 'sept', 'square', 'dec']
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'tri', 'square', 'nana', 'hex', 'dec', 'pent']
# None
# None
# None
# shapes:::: ['nana', 'tri', 'oct', 'sept', 'square', 'dec', 'hex']
# None
# None
# None
# shapes:::: ['hex', 'oct', 'tri', 'dec', 'nana', 'square']
# None
# None
# None
# shapes:::: ['sept', 'dec', 'nana', 'tri', 'oct', 'hex', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'sept', 'tri', 'nana', 'dec', 'pent', 'square']
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'sept', 'tri', 'nana', 'dec', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'tri', 'dec', 'hex', 'sept', 'square', 'nana', 'pent']
# None
# None
# None
# shapes:::: ['hex', 'oct', 'nana', 'dec', 'square', 'sept', 'tri', 'pent']
# None
# None
# shapes:::: ['sept', 'oct', 'dec', 'nana', 'hex', 'pent', 'tri', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'dec', 'square', 'oct', 'hex', 'sept', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'oct', 'nana', 'dec', 'hex', 'pent', 'square']
# None
# None
# None
# shapes:::: ['dec', 'nana', 'oct', 'hex', 'sept', 'square', 'tri', 'pent']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'square', 'sept', 'nana', 'oct', 'tri', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['nana', 'dec', 'oct', 'tri', 'square', 'sept', 'pent', 'hex']
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'nana', 'sept', 'hex', 'tri', 'pent', 'square']
# None
# None
# None
# shapes:::: ['tri', 'sept', 'oct', 'square', 'dec', 'nana', 'hex', 'pent']
# None
# None
# None
# None
# shapes:::: ['dec', 'pent', 'sept', 'oct', 'nana', 'hex', 'tri', 'square']
# None
# None
# shapes:::: ['oct', 'sept', 'tri', 'dec', 'square', 'nana', 'pent', 'hex']
# None
# None
# None
# None
# None
# shapes:::: ['nana', 'oct', 'dec', 'sept', 'hex', 'square', 'tri']
# None
# None
# None
# shapes:::: ['dec', 'oct', 'nana', 'hex', 'sept', 'square', 'tri']
# None
# None
# None
# shapes:::: ['tri', 'oct', 'dec', 'sept', 'nana', 'square', 'pent']
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'sept', 'oct', 'hex', 'dec', 'square']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'square', 'sept', 'nana', 'hex', 'tri', 'pent']
# None
# None
# None
# None
# shapes:::: ['oct', 'sept', 'tri', 'dec', 'hex', 'square', 'nana']
# None
# None
# None
# None
# shapes:::: ['nana', 'dec', 'pent', 'oct', 'sept', 'tri', 'square']
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'tri', 'square', 'nana', 'oct', 'hex', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'nana', 'hex', 'tri', 'sept', 'square']
# None
# None
# None
# shapes:::: ['dec', 'square', 'hex', 'oct', 'tri', 'nana', 'sept']
# None
# None
# None
# shapes:::: ['dec', 'tri', 'oct', 'nana', 'sept', 'square', 'hex']
# None
# shapes:::: ['oct', 'tri', 'dec', 'nana', 'sept', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'dec', 'hex', 'oct', 'nana', 'sept', 'square', 'pent']
# None
# None
# None
# shapes:::: ['oct', 'tri', 'dec', 'hex', 'sept', 'nana', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'oct', 'hex', 'sept', 'dec', 'square']
# None
# None
# None
# shapes:::: ['dec', 'hex', 'oct', 'tri', 'nana', 'sept', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'oct', 'dec', 'hex', 'sept', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['square', 'dec', 'oct', 'nana', 'hex', 'tri', 'sept', 'pent']
# None
# None
# None
# shapes:::: ['dec', 'tri', 'square', 'oct', 'sept', 'nana', 'pent', 'hex']
# None
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'nana', 'hex', 'tri', 'square', 'sept']
# None
# None
# None
# None
# shapes:::: ['nana', 'dec', 'hex', 'oct', 'sept', 'square', 'tri', 'pent']
# None
# shapes:::: ['nana', 'dec', 'hex', 'oct', 'tri', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'dec', 'oct', 'square', 'nana', 'sept', 'hex']
# None
# shapes:::: ['sept', 'tri', 'hex', 'oct', 'nana', 'dec', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'tri', 'nana', 'oct', 'square', 'sept']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'tri', 'sept', 'nana', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'hex', 'oct', 'square', 'tri', 'sept', 'nana']
# None
# None
# None
# None
# shapes:::: ['tri', 'oct', 'nana', 'dec', 'sept', 'pent', 'square']
# None
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['nana', 'square', 'hex', 'oct', 'dec', 'tri', 'sept']
# None
# None
# None
# shapes:::: ['dec', 'sept', 'oct', 'nana', 'square', 'tri']
# None
# None
# None
# shapes:::: ['dec', 'sept', 'oct', 'nana', 'hex', 'tri', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'nana', 'hex', 'square', 'sept', 'tri', 'dec']
# None
# None
# None
# None
# None
# None
# shapes:::: ['square', 'oct', 'tri', 'dec', 'nana', 'hex', 'sept']
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'square', 'hex', 'sept', 'tri', 'pent']
# None
# None
# None
# shapes:::: ['tri', 'dec', 'oct', 'square', 'nana', 'hex', 'sept']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'oct', 'dec', 'hex', 'sept', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['sept', 'square', 'oct', 'dec', 'nana', 'tri', 'hex', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'nana', 'oct', 'tri', 'sept', 'square', 'hex', 'pent']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'sept', 'oct', 'nana', 'hex', 'square', 'tri', 'pent']
# None
# None
# shapes:::: ['tri', 'dec', 'sept', 'oct', 'nana', 'square', 'hex', 'pent']
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'hex', 'oct', 'dec', 'sept', 'square', 'pent']
# None
# None
# shapes:::: ['tri', 'dec', 'oct', 'nana', 'sept', 'square', 'hex']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'tri', 'hex', 'oct', 'sept', 'nana', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'tri', 'nana', 'square', 'hex', 'dec']
# None
# None
# shapes:::: ['dec', 'nana', 'oct', 'tri', 'sept', 'square', 'hex']
# None
# None
# None
# shapes:::: ['sept', 'oct', 'square', 'nana', 'tri', 'pent', 'dec', 'hex']
# None
# None
# None
# None
# shapes:::: ['tri', 'dec', 'sept', 'oct', 'nana', 'square', 'hex', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['square', 'nana', 'sept', 'oct', 'tri', 'dec', 'hex', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'oct', 'nana', 'dec', 'sept', 'hex', 'square']
# None
# None
# None
# None
# shapes:::: ['square', 'dec', 'hex', 'oct', 'nana', 'tri', 'pent']
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'tri', 'nana', 'sept', 'square', 'hex']
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['pent', 'square', 'dec', 'nana', 'tri', 'oct', 'sept']
# None
# None
# None
# None
# shapes:::: ['square', 'dec', 'oct', 'nana', 'tri', 'pent', 'hex']
# None
# None
# None
# shapes:::: ['sept', 'dec', 'oct', 'nana', 'hex', 'square', 'tri', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'square', 'hex', 'oct', 'dec', 'nana', 'pent', 'sept']
# None
# None
# shapes:::: ['tri', 'dec', 'nana', 'oct', 'sept', 'square', 'pent', 'hex']
# None
# None
# None
# None
# None
# shapes:::: ['square', 'oct', 'dec', 'nana', 'tri', 'sept', 'hex']
# None
# None
# None
# None
# None
# None
# shapes:::: ['pent', 'tri', 'hex', 'oct', 'sept', 'dec', 'square', 'nana']
# None
# None
# None
# None
# None
# shapes:::: ['hex', 'nana', 'dec', 'sept', 'oct', 'tri', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'nana', 'dec', 'tri', 'hex', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'square', 'dec', 'nana', 'sept', 'tri']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'square', 'tri', 'sept', 'nana', 'hex', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'square', 'dec', 'tri', 'nana', 'hex', 'sept', 'pent']
# None
# None
# None
# None
# shapes:::: ['square', 'tri', 'sept', 'nana', 'oct', 'hex', 'dec', 'pent']
# None
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'pent', 'dec', 'tri', 'nana', 'hex', 'sept', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'tri', 'dec', 'nana', 'sept', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'pent', 'nana', 'dec', 'sept', 'tri', 'square']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'tri', 'nana', 'square', 'sept', 'pent']
# None
# None
# None
# shapes:::: ['square', 'dec', 'hex', 'oct', 'tri', 'nana', 'sept', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'dec', 'tri', 'nana', 'hex', 'square', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['nana', 'tri', 'dec', 'oct', 'sept', 'hex', 'square', 'pent']
# None
# None
# None
# None
# shapes:::: ['hex', 'oct', 'square', 'dec', 'tri', 'nana', 'pent']
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'tri', 'nana', 'square', 'sept', 'pent']
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'nana', 'sept', 'dec', 'oct', 'square', 'pent']
# None
# None
# shapes:::: ['pent', 'nana', 'tri', 'oct', 'sept', 'hex', 'square', 'dec']
# None
# None
# None
# None
# shapes:::: ['dec', 'nana', 'tri', 'oct', 'square', 'sept', 'hex']
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'tri', 'nana', 'sept', 'square', 'pent']
# None
# None
# shapes:::: ['tri', 'nana', 'sept', 'oct', 'dec', 'hex', 'square', 'pent']
# None
# None
# None
# None
# None
# shapes:::: ['square', 'sept', 'oct', 'dec', 'hex', 'tri', 'nana', 'pent']
# None
# None
# None
# None
# None
# None
# None
# None
# shapes:::: ['nana', 'square', 'hex', 'dec', 'oct', 'sept', 'tri']
# None
# None
# None
# None
# None
# None
# shapes:::: ['sept', 'oct', 'tri', 'square', 'dec', 'nana', 'pent']
# None
# None
# None
# None
# shapes:::: ['tri', 'square', 'dec', 'nana', 'oct', 'sept', 'hex', 'pent']
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'sept', 'nana', 'tri', 'pent', 'square']
# None
# None
# None
# None
# None
# shapes:::: ['dec', 'oct', 'sept', 'nana', 'square', 'tri', 'pent', 'hex']
# None
# None
# None
# None
# None
# shapes:::: ['oct', 'dec', 'nana', 'tri', 'sept', 'square']
# None
# None
# None
# None
# None
# None
# shapes:::: ['tri', 'oct', 'dec', 'nana', 'sept', 'pent', 'square']

# %%
print(check_shapes)
# Out:
# {'tri': 125, 'square': 124, 'pent': 82, 'hex': 103, 'sept': 116, 'oct': 125, 'nana': 124, 'dec': 125}
